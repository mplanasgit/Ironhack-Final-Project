# %% [markdown]
# **Ironhack Final Project**
#
# ---
#
# **Notebook 00 - EDA**
#
# ---

# %% [markdown]
# **Libraries**

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import tools.download as dwn
import os
import glob

# %% [markdown]
# # Downloading data

# %% [markdown]
# ## Barcelona

# %% [markdown]
# Air quality data downloaded from the European Environment Agency. Settings:
# - Country: ES Spain
# - City name: Barcelona
# - Pollutant: PM2.5
# - Year from: 2013
# - Year to: 2022
# - Source: All
# - Output type: HTML
# - Update date: *empty*
# - Time coverage: Year

# %%
# Create list of links to download (csv files)
url = 'https://fme.discomap.eea.europa.eu/fmedatastreaming/AirQualityDownload/AQData_Extract.fmw?CountryCode=ES&CityName=Barcelona&Pollutant=6001&Year_from=2013&Year_to=2022&Station=&Samplingpoint=&Source=All&Output=HTML&UpdateDate=&TimeCoverage=Year'
barcelona_EEA = dwn.get_list_htmls_EEA (url)

# %%
barcelona_EEA[:2]
# Out:
# ['https://ereporting.blob.core.windows.net/downloadservice/ES_6001_15256_2013_timeseries.csv',
#  'https://ereporting.blob.core.windows.net/downloadservice/ES_6001_11907_2013_timeseries.csv']

# %%
# Save into directory
dwn.save_into_dir_EEA('../data/EEA/barcelona', barcelona_EEA)
# Out:
# 'files saved successfully!'

# %%
# Concatenate files
dwn.concatenate_csv('../data/EEA/barcelona', 'barcelona_combined.csv')
# Out:
# 'files combined successfully!'

# %%
test = pd.read_csv('../data/EEA/barcelona/barcelona_combined.csv')

# %%
test
# Out:
#       Countrycode    Namespace AirQualityNetwork AirQualityStation  \
# 0              ES  ES.BDCA.AQD        NET_ES209A       STA_ES1438A
# 1              ES  ES.BDCA.AQD        NET_ES209A       STA_ES1438A
# 2              ES  ES.BDCA.AQD        NET_ES209A       STA_ES1438A
# 3              ES  ES.BDCA.AQD        NET_ES209A       STA_ES1438A
# 4              ES  ES.BDCA.AQD        NET_ES209A       STA_ES1438A
# ...           ...          ...               ...               ...
# 31613          ES  ES.BDCA.AQD        NET_ES209A       STA_ES0691A
# 31614          ES  ES.BDCA.AQD        NET_ES209A       STA_ES0691A
# 31615          ES  ES.BDCA.AQD        NET_ES209A       STA_ES0691A
# 31616          ES  ES.BDCA.AQD        NET_ES209A       STA_ES0691A
# 31617          ES  ES.BDCA.AQD        NET_ES209A       STA_ES0691A
#
#       AirQualityStationEoICode    SamplingPoint     SamplingProcess  \
# 0                      ES1438A  SP_08019043_9_M  SPP_08019043_9_M.1
# 1                      ES1438A  SP_08019043_9_M  SPP_08019043_9_M.1
# 2                      ES1438A  SP_08019043_9_M  SPP_08019043_9_M.1
# 3                      ES1438A  SP_08019043_9_M  SPP_08019043_9_M.1
# 4                      ES1438A  SP_08019043_9_M  SPP_08019043_9_M.1
# ...                        ...              ...                 ...
# 31613                  ES0691A  SP_08019004_9_M  SPP_08019004_9_M.1
# 31614                  ES0691A  SP_08019004_9_M  SPP_08019004_9_M.1
# 31615                  ES0691A  SP_08019004_9_M  SPP_08019004_9_M.1
# 31616                  ES0691A  SP_08019004_9_M  SPP_08019004_9_M.1
# 31617                  ES0691A  SP_08019004_9_M  SPP_08019004_9_M.1
#
#                  Sample AirPollutant  \
# 0      SAM_08019043_9_M        PM2.5
# 1      SAM_08019043_9_M        PM2.5
# 2      SAM_08019043_9_M        PM2.5
# 3      SAM_08019043_9_M        PM2.5
# 4      SAM_08019043_9_M        PM2.5
# ...                 ...          ...
# 31613  SAM_08019004_9_M        PM2.5
# 31614  SAM_08019004_9_M        PM2.5
# 31615  SAM_08019004_9_M        PM2.5
# 31616  SAM_08019004_9_M        PM2.5
# 31617  SAM_08019004_9_M        PM2.5
#
#                                         AirPollutantCode AveragingTime  \
# 0      http://dd.eionet.europa.eu/vocabulary/aq/pollu...           day
# 1      http://dd.eionet.europa.eu/vocabulary/aq/pollu...           day
# 2      http://dd.eionet.europa.eu/vocabulary/aq/pollu...           day
# 3      http://dd.eionet.europa.eu/vocabulary/aq/pollu...           day
# 4      http://dd.eionet.europa.eu/vocabulary/aq/pollu...           day
# ...                                                  ...           ...
# 31613  http://dd.eionet.europa.eu/vocabulary/aq/pollu...           day
# 31614  http://dd.eionet.europa.eu/vocabulary/aq/pollu...           day
# 31615  http://dd.eionet.europa.eu/vocabulary/aq/pollu...           day
# 31616  http://dd.eionet.europa.eu/vocabulary/aq/pollu...           day
# 31617  http://dd.eionet.europa.eu/vocabulary/aq/pollu...           day
#
#        Concentration UnitOfMeasurement               DatetimeBegin  \
# 0               14.2             µg/m3  2013-10-19 00:00:00 +01:00
# 1                NaN             µg/m3  2013-01-07 00:00:00 +01:00
# 2               16.4             µg/m3  2013-10-17 00:00:00 +01:00
# 3               20.9             µg/m3  2013-10-22 00:00:00 +01:00
# 4               19.6             µg/m3  2013-10-16 00:00:00 +01:00
# ...              ...               ...                         ...
# 31613           10.7             µg/m3  2020-12-27 00:00:00 +01:00
# 31614            NaN             µg/m3  2020-12-28 00:00:00 +01:00
# 31615            NaN             µg/m3  2020-12-29 00:00:00 +01:00
# 31616            NaN             µg/m3  2020-12-30 00:00:00 +01:00
# 31617            NaN             µg/m3  2020-12-31 00:00:00 +01:00
#
#                       DatetimeEnd  Validity  Verification
# 0      2013-10-20 00:00:00 +01:00         1             1
# 1      2013-01-08 00:00:00 +01:00        -1             1
# 2      2013-10-18 00:00:00 +01:00         1             1
# 3      2013-10-23 00:00:00 +01:00         1             1
# 4      2013-10-17 00:00:00 +01:00         1             1
# ...                           ...       ...           ...
# 31613  2020-12-28 00:00:00 +01:00         1             1
# 31614  2020-12-29 00:00:00 +01:00        -1             1
# 31615  2020-12-30 00:00:00 +01:00        -1             1
# 31616  2020-12-31 00:00:00 +01:00        -1             1
# 31617  2021-01-01 00:00:00 +01:00        -1             1
#
# [31618 rows x 17 columns]

# %%
test.isna().sum()
# Out:
# Countrycode                    0
# Namespace                      0
# AirQualityNetwork              0
# AirQualityStation              0
# AirQualityStationEoICode       0
# SamplingPoint                  0
# SamplingProcess                0
# Sample                         0
# AirPollutant                   0
# AirPollutantCode               0
# AveragingTime                  0
# Concentration               4663
# UnitOfMeasurement              0
# DatetimeBegin                  0
# DatetimeEnd                    0
# Validity                       0
# Verification                   0
# dtype: int64
